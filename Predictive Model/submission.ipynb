# %% [markdown]
# # USA Restaurant Recommendation - Content Based

# %% [markdown]
# **About the DataSet**
#
# This dataset can be accesed through this: [Kaggle](https://www.kaggle.com/datasets/siddharthmandgi/tripadvisor-restaurant-recommendation-data-usa/data)
#
# - Name of the Restaurant : Restaurant Name
# - Street Address : Restaurant Address
# - Location : Detail Location, City, Country and PostCode
# - Type of Cuisine Served : Cuisine
# - Contact Number : Restaurant Contact Number
# - TripAdvisor Restuarant URL : Restaurant URL
# - Menu URL : Restaurant Menu URL

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
# Load Data
restaurant = pd.read_csv('TripAdvisor_RestauarantRecommendation.csv', delimiter=',')
restaurant.head(3)
# Out:
#                             Name       Street Address  \
# 0  Betty Lou's Seafood and Grill     318 Columbus Ave
# 1              Coach House Diner        55 State Rt 4
# 2               Table Talk Diner  2521 South Rd Ste C
#
#                        Location                                          Type  \
# 0  San Francisco, CA 94133-3908   Seafood, Vegetarian Friendly, Vegan Options
# 1     Hackensack, NJ 07601-6337          Diner, American, Vegetarian Friendly
# 2   Poughkeepsie, NY 12601-5476          American, Diner, Vegetarian Friendly
#
#             Reviews No of Reviews  \
# 0  4.5 of 5 bubbles   243 reviews
# 1    4 of 5 bubbles    84 reviews
# 2    4 of 5 bubbles   256 reviews
#
#                                             Comments   Contact Number  \
# 0                                                NaN  +1 415-757-0569
# 1  Both times we were there very late, after 11 P...  +1 201-488-4999
# 2  Waitress was very friendly but a little pricey...  +1 845-849-2839
#
#                                     Trip_advisor Url  \
# 0  https://www.tripadvisor.com//Restaurant_Review...
# 1  https://www.tripadvisor.com//Restaurant_Review...
# 2  https://www.tripadvisor.com//Restaurant_Review...
#
#                                         Menu Price_Range
# 0               Check The Website for a Menu    $$ - $$$
# 1               Check The Website for a Menu    $$ - $$$
# 2  http://tabletalkdiner.com/menu/breakfast/    $$ - $$$

# %%
print(restaurant['Name'].nunique())
# Out:
# 2641

# %%
restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3062 entries, 0 to 3061
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              3062 non-null   object
#  1   Street Address    3062 non-null   object
#  2   Location          3062 non-null   object
#  3   Type              3049 non-null   object
#  4   Reviews           3062 non-null   object
#  5   No of Reviews     3062 non-null   object
#  6   Comments          2447 non-null   object
#  7   Contact Number    3062 non-null   object
#  8   Trip_advisor Url  3062 non-null   object
#  9   Menu              3062 non-null   object
#  10  Price_Range       3062 non-null   object
# dtypes: object(11)
# memory usage: 263.3+ KB

# %% [markdown]
# ### Cleaning Dataset

# %%
# Drop the columns we don't need
drop_cols = ['Street Address', 'Comments', 'Contact Number', 'Trip_advisor Url', 'Menu', 'Price_Range']
restaurant = restaurant.drop(columns=drop_cols)

# %%
# Check Missing Values
restaurant.loc[restaurant.isna().any(axis=1) == True]
# Out:
#                                    Name                    Location Type  \
# 49      Luby's Cafeteria Mall Del Norte                  Laredo, TX  NaN
# 267                          Very Juice     Brooklyn, NY 11223-1935  NaN
# 1000               Cast Iron Trading Co     Stockton, CA 95202-2407  NaN
# 1238  Sir Winston's Restaurant & Lounge   Long Beach, CA 90802-6331  NaN
# 1629   Benji's French Basque Restaurant  Bakersfield, CA 93308-6130  NaN
# 1641                 Chuck's Hamburgers     Stockton, CA 95207-4703  NaN
# 1744                   Wavershak's Deli   Toms River, NJ 08755-1284  NaN
# 2090          Vera's Backyard Bar-B-Que  Brownsville, TX 78521-3765  NaN
# 2230                       Cafe Matisse   Rutherford, NJ 07070-2307  NaN
# 2348               Cast Iron Trading Co     Stockton, CA 95202-2407  NaN
# 2448             Domingo's Italian Deli  Los Angeles, CA 91316-3835  NaN
# 2453                  Peck Peck Chicken      Teaneck, NJ 07666-3206  NaN
# 2866                   Wavershak's Deli   Toms River, NJ 08755-1284  NaN
#
#                Reviews     No of Reviews
# 49      4 of 5 bubbles        27 reviews
# 267     5 of 5 bubbles          1 review
# 1000  4.5 of 5 bubbles        11 reviews
# 1238  4.5 of 5 bubbles       490 reviews
# 1629    4 of 5 bubbles       157 reviews
# 1641  4.5 of 5 bubbles        17 reviews
# 1744         No review  Undefined Number
# 2090  4.5 of 5 bubbles        11 reviews
# 2230  4.5 of 5 bubbles       227 reviews
# 2348  4.5 of 5 bubbles        11 reviews
# 2448  4.5 of 5 bubbles         8 reviews
# 2453    5 of 5 bubbles        36 reviews
# 2866         No review  Undefined Number

# %% [markdown]
# Since the missing values is in column `Type`. There is nothing we can do because this gonna be our recommendation features, along with `Reviews` and `No of Reviews` columns. So this gonna be removed

# %%
# Drop the columns
restaurant = restaurant.dropna()

# %%
# Recheck if there are still exist missing value
restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3049 entries, 0 to 3061
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           3049 non-null   object
#  1   Location       3049 non-null   object
#  2   Type           3049 non-null   object
#  3   Reviews        3049 non-null   object
#  4   No of Reviews  3049 non-null   object
# dtypes: object(5)
# memory usage: 142.9+ KB

# %% [markdown]
# ## Preprocessing

# %%
restaurant.duplicated().sum()
# Out:
# 174

# %%
restaurant.loc[restaurant.duplicated()]
# Out:
#                                Name                      Location  \
# 414              The Capital Grille     Costa Mesa, CA 92626-1873
# 422                   The Slow Bone         Dallas, TX 75207-6202
# 445                    Jackson Hole       East Elmhurst, NY 11370
# 508                Amore Ristorante  Woodland Park, NJ 07424-3305
# 511                 PITHARI TAVERNA  Highland Park, NJ 08904-3234
# ...                             ...                           ...
# 3046                 Scalini Fedeli  New York City, NY 10013-3332
# 3049  The Ranch Restaurant & Saloon        Anaheim, CA 92805-5957
# 3051     Mesob Ethiopian Restaurant      Montclair, NJ 07042-3442
# 3056                       Stamatis             Astoria, NY 11105
# 3058                  City Vineyard       New York City, NY 10013
#
#                                               Type           Reviews  \
# 414      American, Steakhouse, Gluten Free Options  4.5 of 5 bubbles
# 422                             American, Barbecue  4.5 of 5 bubbles
# 445           Greek, American, Vegetarian Friendly  4.5 of 5 bubbles
# 508    Italian, Vegetarian Friendly, Vegan Options  4.5 of 5 bubbles
# 511      Mediterranean, Greek, Vegetarian Friendly    4 of 5 bubbles
# ...                                            ...               ...
# 3046   Italian, Vegetarian Friendly, Vegan Options  4.5 of 5 bubbles
# 3049     American, Steakhouse, Vegetarian Friendly  4.5 of 5 bubbles
# 3051       Ethiopian, African, Vegetarian Friendly  4.5 of 5 bubbles
# 3056     Mediterranean, Greek, Vegetarian Friendly  4.5 of 5 bubbles
# 3058                        American, Bar, Seafood  4.5 of 5 bubbles
#
#      No of Reviews
# 414    399 reviews
# 422    236 reviews
# 445    167 reviews
# 508     88 reviews
# 511    201 reviews
# ...            ...
# 3046   427 reviews
# 3049   398 reviews
# 3051   223 reviews
# 3056   247 reviews
# 3058   374 reviews
#
# [174 rows x 5 columns]

# %%
restaurant.loc[restaurant['Name'] == 'The Capital Grille']
# Out:
#                     Name                      Location  \
# 40    The Capital Grille         Austin, TX 78701-3914
# 65    The Capital Grille  New York City, NY 10017-5608
# 171   The Capital Grille        Houston, TX 77056-5402
# 391   The Capital Grille     Costa Mesa, CA 92626-1873
# 414   The Capital Grille     Costa Mesa, CA 92626-1873
# 562   The Capital Grille    Cherry Hill, NJ 08002-2100
# 1311  The Capital Grille          Plano, TX 75024-4013
# 2126  The Capital Grille        Paramus, NJ 07652-2404
# 2444  The Capital Grille         Dallas, TX 75201-1894
# 2489  The Capital Grille     Fort Worth, TX 76102-6247
# 2794  The Capital Grille        Seattle, WA 98101-2550
#
#                                             Type           Reviews  \
# 40     American, Steakhouse, Gluten Free Options  4.5 of 5 bubbles
# 65     American, Steakhouse, Vegetarian Friendly  4.5 of 5 bubbles
# 171    American, Steakhouse, Vegetarian Friendly  4.5 of 5 bubbles
# 391    American, Steakhouse, Gluten Free Options  4.5 of 5 bubbles
# 414    American, Steakhouse, Gluten Free Options  4.5 of 5 bubbles
# 562    American, Steakhouse, Gluten Free Options  4.5 of 5 bubbles
# 1311         American, Steakhouse, Vegan Options  4.5 of 5 bubbles
# 2126   American, Steakhouse, Gluten Free Options  4.5 of 5 bubbles
# 2444   American, Steakhouse, Vegetarian Friendly  4.5 of 5 bubbles
# 2489   American, Steakhouse, Vegetarian Friendly  4.5 of 5 bubbles
# 2794   American, Steakhouse, Vegetarian Friendly  4.5 of 5 bubbles
#
#      No of Reviews
# 40     240 reviews
# 65     932 reviews
# 171    428 reviews
# 391    399 reviews
# 414    399 reviews
# 562    345 reviews
# 1311   485 reviews
# 2126   276 reviews
# 2444   437 reviews
# 2489   692 reviews
# 2794   599 reviews

# %%
restaurant = restaurant.drop_duplicates()

# %%
restaurant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2875 entries, 0 to 3061
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           2875 non-null   object
#  1   Location       2875 non-null   object
#  2   Type           2875 non-null   object
#  3   Reviews        2875 non-null   object
#  4   No of Reviews  2875 non-null   object
# dtypes: object(5)
# memory usage: 134.8+ KB

# %% [markdown]
# Get the City, and Country. Change Reviews and No of Reviews to float to get Weighted Reviews. All of that features gonna be recommendation reasons

# %%
restaurant['City'] = restaurant['Location'].apply(lambda text: text.split(',')[0])
restaurant['Country'] = restaurant['Location'].apply(lambda text: text.split(',')[1] # Split first
                            .split(' ')[1] # Split second to get country
                            .replace(" ", "") # Remove White Space
                            )

restaurant['Reviews'] = restaurant['Reviews'].apply(lambda text: text.split(' ')[0]).astype(float)
restaurant['No of Reviews'] = restaurant['No of Reviews'].apply(lambda text: text.split(' ')[0]
                                                                .replace(',', '')
                                                                ).astype(float)

restaurant['Weighted Reviews'] = restaurant['Reviews']*restaurant['No of Reviews']

# %%
from sklearn.preprocessing import MinMaxScaler
# Standardize the Reviews and No of Reviews
mm = MinMaxScaler()

restaurant['Weighted Reviews'] = mm.fit_transform(restaurant['Weighted Reviews'].values.reshape(-1, 1))

# %%
# Set restaurant name as index
restaurant.set_index('Name', inplace=True)

# %% [markdown]
# ## Modelling

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

tfidf_city = TfidfVectorizer()

stop_words = stopwords.words('english') 
tfidf_type = TfidfVectorizer(stop_words=stop_words)

tfidf_country = TfidfVectorizer()

# %%
# Fit and transform to matrix
city_matrix = tfidf_city.fit_transform(restaurant['City'])
type_matrix = tfidf_type.fit_transform(restaurant['Type'])
country_matrix = tfidf_country.fit_transform(restaurant['Country'])

# %%
# Convert the sparse matrix to a DataFrame
city_df = pd.DataFrame(city_matrix.toarray(), columns=tfidf_city.get_feature_names_out(), index=restaurant.index)
type_df = pd.DataFrame(type_matrix.toarray(), columns=tfidf_type.get_feature_names_out(), index=restaurant.index)
country_df = pd.DataFrame(country_matrix.toarray(), columns=tfidf_country.get_feature_names_out(), index=restaurant.index)

reviews_df = pd.DataFrame(index=restaurant.index, data=restaurant['Weighted Reviews'])

# Concatenate the DataFrames
main_data = pd.concat([city_df, type_df, country_df, reviews_df], axis=1)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Compute the cosine similarity matrix
cosine_sim = cosine_similarity(main_data)

# Convert the cosine similarity matrix to a DataFrame
cosine_sim_df = pd.DataFrame(cosine_sim, index=main_data.index, columns=main_data.index)

# %%
cosine_sim_df
# Out:
# Name                           Betty Lou's Seafood and Grill  \
# Name
# Betty Lou's Seafood and Grill                       1.000000
# Coach House Diner                                   0.066114
# Table Talk Diner                                    0.066612
# Sixty Vines                                         0.052185
# The Clam Bar                                        0.142550
# ...                                                      ...
# Grazie                                              0.234521
# Indigo Kitchen & Ale House                          0.086832
# BRIO Tuscan Grille                                  0.000622
# Maywood Pancake house                               0.165246
# Porto Leggero                                       0.234043
#
# Name                           Coach House Diner  Table Talk Diner  \
# Name
# Betty Lou's Seafood and Grill           0.066114          0.066612
# Coach House Diner                       1.000000          0.333427
# Table Talk Diner                        0.333427          1.000000
# Sixty Vines                             0.084213          0.084687
# The Clam Bar                            0.039344          0.372941
# ...                                          ...               ...
# Grazie                                  0.070216          0.403889
# Indigo Kitchen & Ale House              0.140988          0.141364
# BRIO Tuscan Grille                      0.333425          0.000581
# Maywood Pancake house                   0.356092          0.022935
# Porto Leggero                           0.403322          0.070442
#
# Name                           Sixty Vines  The Clam Bar  E Tutto Qua  \
# Name
# Betty Lou's Seafood and Grill     0.052185      0.142550     0.776587
# Coach House Diner                 0.084213      0.039344     0.001382
# Table Talk Diner                  0.084687      0.372941     0.004390
# Sixty Vines                       1.000000      0.108108     0.004537
# The Clam Bar                      0.108108      1.000000     0.148567
# ...                                    ...           ...          ...
# Grazie                            0.055717      0.334174     0.088936
# Indigo Kitchen & Ale House        0.199358      0.180558     0.003809
# BRIO Tuscan Grille                0.067351      0.097347     0.087490
# Maywood Pancake house             0.017960      0.025930     0.001435
# Porto Leggero                     0.055126      0.000632     0.085205
#
# Name                           Black Angus Steakhouse - Federal Way  Ziziki's  \
# Name
# Betty Lou's Seafood and Grill                              0.000649  0.000287
# Coach House Diner                                          0.037502  0.000085
# Table Talk Diner                                           0.037906  0.000269
# Sixty Vines                                                0.103022  0.333468
# The Clam Bar                                               0.149012  0.000300
# ...                                                             ...       ...
# Grazie                                                     0.001010  0.000447
# Indigo Kitchen & Ale House                                 0.505348  0.000233
# BRIO Tuscan Grille                                         0.267302  0.000220
# Maywood Pancake house                                      0.024698  0.000088
# Porto Leggero                                              0.000486  0.000215
#
# Name                           Vince's Italian Restaurant & Pizzeria  \
# Name
# Betty Lou's Seafood and Grill                               0.067291
# Coach House Diner                                           0.074404
# Table Talk Diner                                            0.074544
# Sixty Vines                                                 0.058246
# The Clam Bar                                                0.000268
# ...                                                              ...
# Grazie                                                      0.162317
# Indigo Kitchen & Ale House                                  0.430672
# BRIO Tuscan Grille                                          0.093553
# Maywood Pancake house                                       0.000078
# Porto Leggero                                               0.162232
#
# Name                           John Thomas Steakhouse  ...  Buffalo Chophouse  \
# Name                                                   ...
# Betty Lou's Seafood and Grill                0.056343  ...           0.000941
# Coach House Diner                            0.026483  ...           0.044990
# Table Talk Diner                             0.360060  ...           0.378612
# Sixty Vines                                  0.021227  ...           0.035799
# The Clam Bar                                 0.363545  ...           0.384529
# ...                                               ...  ...                ...
# Grazie                                       0.393003  ...           0.334289
# Indigo Kitchen & Ale House                   0.034970  ...           0.059255
# BRIO Tuscan Grille                           0.123409  ...           0.209866
# Maywood Pancake house                        0.246711  ...           0.029649
# Porto Leggero                                0.059544  ...           0.000705
#
# Name                           The Glass Tavern  Uncle Bill's Pancake House  \
# Name
# Betty Lou's Seafood and Grill          0.142200                    0.116671
# Coach House Diner                      0.039240                    0.522764
# Table Talk Diner                       0.372689                    0.190012
# Sixty Vines                            0.107760                    0.148498
# The Clam Bar                           0.666759                    0.069593
# ...                                         ...                         ...
# Grazie                                 0.333665                    0.222899
# Indigo Kitchen & Ale House             0.180294                    0.248320
# BRIO Tuscan Grille                     0.097074                    0.333729
# Maywood Pancake house                  0.025817                    0.373386
# Porto Leggero                          0.000337                    0.554186
#
# Name                           El Mexicano  Crave Fishbar    Grazie  \
# Name
# Betty Lou's Seafood and Grill     0.000908       0.108654  0.234521
# Coach House Diner                 0.000267       0.030003  0.070216
# Table Talk Diner                  0.333895       0.363704  0.403889
# Sixty Vines                       0.000878       0.024459  0.055717
# The Clam Bar                      0.333964       0.502097  0.334174
# ...                                    ...            ...       ...
# Grazie                            0.334250       0.667394  1.000000
# Indigo Kitchen & Ale House        0.000737       0.039855  0.092390
# BRIO Tuscan Grille                0.000697       0.001092  0.088692
# Maywood Pancake house             0.000278       0.019861  0.175325
# Porto Leggero                     0.000680       0.091616  0.424450
#
# Name                           Indigo Kitchen & Ale House  BRIO Tuscan Grille  \
# Name
# Betty Lou's Seafood and Grill                    0.086832            0.000622
# Coach House Diner                                0.140988            0.333425
# Table Talk Diner                                 0.141364            0.000581
# Sixty Vines                                      0.199358            0.067351
# The Clam Bar                                     0.180558            0.097347
# ...                                                   ...                 ...
# Grazie                                           0.092390            0.088692
# Indigo Kitchen & Ale House                       1.000000            0.112410
# BRIO Tuscan Grille                               0.112410            1.000000
# Maywood Pancake house                            0.029910            0.333431
# Porto Leggero                                    0.091928            0.421434
#
# Name                           Maywood Pancake house  Porto Leggero
# Name
# Betty Lou's Seafood and Grill               0.165246       0.234043
# Coach House Diner                           0.356092       0.403322
# Table Talk Diner                            0.022935       0.070442
# Sixty Vines                                 0.017960       0.055126
# The Clam Bar                                0.025930       0.000632
# ...                                              ...            ...
# Grazie                                      0.175325       0.424450
# Indigo Kitchen & Ale House                  0.029910       0.091928
# BRIO Tuscan Grille                          0.333431       0.421434
# Maywood Pancake house                       1.000000       0.508502
# Porto Leggero                               0.508502       1.000000
#
# [2875 rows x 2875 columns]

# %% [markdown]
# ## Evaluation

# %%
def recommend_restaurants(restaurant_name, cosine_sim_df=cosine_sim_df, restaurant_data=restaurant, top=5):
    
    index = cosine_sim_df.loc[:, restaurant_name].to_numpy().argpartition(
        range(-1, -top, -1)
    )

    closest = cosine_sim_df.columns[index[-1:-(top+2):-1]]

    closest = closest.drop(restaurant_name, errors='ignore')

    return restaurant_data.loc[closest,]

# %%
restaurant.loc["Betty Lou's Seafood and Grill",:]
# Out:
# Location                            San Francisco, CA 94133-3908
# Type                 Seafood, Vegetarian Friendly, Vegan Options
# Reviews                                                      4.5
# No of Reviews                                              243.0
# City                                               San Francisco
# Country                                                       CA
# Weighted Reviews                                        0.049306
# Name: Betty Lou's Seafood and Grill, dtype: object

# %%
# Test the recommendation system with Random Restaurant
recommend_restaurants("Betty Lou's Seafood and Grill")
# Out:
#                                           Location  \
# Name
# Ristorante Franchino  San Francisco, CA 94133-3907
# Seven Hills           San Francisco, CA 94109-3114
# Quince                San Francisco, CA 94133-4610
# Pacific Cafe          San Francisco, CA 94121-1623
# Pacific Catch         San Francisco, CA 94123-2701
#
#                                                               Type  Reviews  \
# Name
# Ristorante Franchino   Italian, Vegetarian Friendly, Vegan Options      4.5
# Seven Hills                  Seafood, Italian, Vegetarian Friendly      4.5
# Quince                  French, Vegetarian Friendly, Vegan Options      4.5
# Pacific Cafe                American, Seafood, Gluten Free Options      4.5
# Pacific Catch               Hawaiian, Seafood, Vegetarian Friendly      4.5
#
#                       No of Reviews           City Country  Weighted Reviews
# Name
# Ristorante Franchino          429.0  San Francisco      CA          0.087750
# Seven Hills                   923.0  San Francisco      CA          0.189854
# Quince                        545.0  San Francisco      CA          0.111726
# Pacific Cafe                  241.0  San Francisco      CA          0.048893
# Pacific Catch                 987.0  San Francisco      CA          0.203082
